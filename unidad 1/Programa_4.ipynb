# %% [markdown]
# <a href="https://colab.research.google.com/github/GeoDrk/Prob.-Y-Estadistica/blob/main/unidad%201/Programa_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unidad 1
#
# # Práctica 4
# #Tabla de frecuencias
#
# Docente; Dr. José Gabriel Rodriguez Rivas
#
# Alumno: Geovanni Joel Ramirez Rivas

# %%
import random
edades = []
#ciclo para generar 100 numeros aleatorios (representan edades)
for i in range(100):
  #Generamos un numero aleatorio y lo guardamos en la variable randint
  numero_aleatorio = random.randint( 18,70 )
  #Agregamos el numero a la lista de valores
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [62, 63, 38, 46, 52, 56, 53, 27, 51, 65, 48, 62, 67, 20, 68, 25, 33, 56, 30, 40, 44, 31, 30, 45, 19, 21, 35, 25, 55, 40, 34, 29, 18, 23, 33, 42, 64, 19, 57, 67, 50, 41, 64, 38, 69, 63, 40, 62, 28, 31, 46, 24, 57, 38, 45, 25, 19, 50, 49, 22, 63, 44, 60, 67, 40, 34, 66, 20, 23, 38, 25, 36, 38, 24, 51, 47, 33, 40, 35, 64, 56, 33, 43, 56, 58, 55, 68, 23, 35, 25, 62, 58, 35, 55, 29, 49, 19, 29, 26, 22]

# %%
import pandas as pd

# %%
df = pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    62
# 1    63
# 2    38
# 3    46
# 4    52

# %%
#Generar una tabla de distribucion de frecuencia
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')

#Imprimir la tabla
print("Tabla de Distribución de Frecuencia:")
tabla_frecuencias
# Out:
# Tabla de Distribución de Frecuencia:
#     Edad  Frecuencia
# 39    18           1
# 4     19           4
# 26    20           2
# 40    21           1
# 17    22           2
# 12    23           3
# 28    24           2
# 0     25           5
# 45    26           1
# 35    27           1
# 29    28           1
# 8     29           3
# 24    30           2
# 22    31           2
# 5     33           4
# 19    34           2
# 6     35           4
# 31    36           1
# 1     38           5
# 2     40           5
# 37    41           1
# 38    42           1
# 34    43           1
# 23    44           2
# 21    45           2
# 20    46           2
# 33    47           1
# 43    48           1
# 14    49           2
# 15    50           2
# 18    51           2
# 41    52           1
# 42    53           1
# 13    55           3
# 7     56           4
# 16    57           2
# 27    58           2
# 32    60           1
# 3     62           4
# 9     63           3
# 11    64           3
# 44    65           1
# 30    66           1
# 10    67           3
# 25    68           2
# 36    69           1

# %%
tabla_frecuencias['Frec Relativa'] = tabla_frecuencias['Frecuencia']/100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 39    18           1           0.01
# 4     19           4           0.04
# 26    20           2           0.02
# 40    21           1           0.01
# 17    22           2           0.02
# 12    23           3           0.03
# 28    24           2           0.02
# 0     25           5           0.05
# 45    26           1           0.01
# 35    27           1           0.01
# 29    28           1           0.01
# 8     29           3           0.03
# 24    30           2           0.02
# 22    31           2           0.02
# 5     33           4           0.04
# 19    34           2           0.02
# 6     35           4           0.04
# 31    36           1           0.01
# 1     38           5           0.05
# 2     40           5           0.05
# 37    41           1           0.01
# 38    42           1           0.01
# 34    43           1           0.01
# 23    44           2           0.02
# 21    45           2           0.02
# 20    46           2           0.02
# 33    47           1           0.01
# 43    48           1           0.01
# 14    49           2           0.02
# 15    50           2           0.02
# 18    51           2           0.02
# 41    52           1           0.01
# 42    53           1           0.01
# 13    55           3           0.03
# 7     56           4           0.04
# 16    57           2           0.02
# 27    58           2           0.02
# 32    60           1           0.01
# 3     62           4           0.04
# 9     63           3           0.03
# 11    64           3           0.03
# 44    65           1           0.01
# 30    66           1           0.01
# 10    67           3           0.03
# 25    68           2           0.02
# 36    69           1           0.01

# %%
tabla_frecuencias['Frec Porcentual'] = tabla_frecuencias['Frecuencia'] /100 *100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual
# 39    18           1           0.01              1.0
# 4     19           4           0.04              4.0
# 26    20           2           0.02              2.0
# 40    21           1           0.01              1.0
# 17    22           2           0.02              2.0
# 12    23           3           0.03              3.0
# 28    24           2           0.02              2.0
# 0     25           5           0.05              5.0
# 45    26           1           0.01              1.0
# 35    27           1           0.01              1.0
# 29    28           1           0.01              1.0
# 8     29           3           0.03              3.0
# 24    30           2           0.02              2.0
# 22    31           2           0.02              2.0
# 5     33           4           0.04              4.0
# 19    34           2           0.02              2.0
# 6     35           4           0.04              4.0
# 31    36           1           0.01              1.0
# 1     38           5           0.05              5.0
# 2     40           5           0.05              5.0
# 37    41           1           0.01              1.0
# 38    42           1           0.01              1.0
# 34    43           1           0.01              1.0
# 23    44           2           0.02              2.0
# 21    45           2           0.02              2.0
# 20    46           2           0.02              2.0
# 33    47           1           0.01              1.0
# 43    48           1           0.01              1.0
# 14    49           2           0.02              2.0
# 15    50           2           0.02              2.0
# 18    51           2           0.02              2.0
# 41    52           1           0.01              1.0
# 42    53           1           0.01              1.0
# 13    55           3           0.03              3.0
# 7     56           4           0.04              4.0
# 16    57           2           0.02              2.0
# 27    58           2           0.02              2.0
# 32    60           1           0.01              1.0
# 3     62           4           0.04              4.0
# 9     63           3           0.03              3.0
# 11    64           3           0.03              3.0
# 44    65           1           0.01              1.0
# 30    66           1           0.01              1.0
# 10    67           3           0.03              3.0
# 25    68           2           0.02              2.0
# 36    69           1           0.01              1.0

# %%
tabla_frecuencias['Frec Acumulada'] = tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acumulada
# 39    18           1           0.01              1.0               1
# 4     19           4           0.04              4.0               5
# 26    20           2           0.02              2.0               7
# 40    21           1           0.01              1.0               8
# 17    22           2           0.02              2.0              10
# 12    23           3           0.03              3.0              13
# 28    24           2           0.02              2.0              15
# 0     25           5           0.05              5.0              20
# 45    26           1           0.01              1.0              21
# 35    27           1           0.01              1.0              22
# 29    28           1           0.01              1.0              23
# 8     29           3           0.03              3.0              26
# 24    30           2           0.02              2.0              28
# 22    31           2           0.02              2.0              30
# 5     33           4           0.04              4.0              34
# 19    34           2           0.02              2.0              36
# 6     35           4           0.04              4.0              40
# 31    36           1           0.01              1.0              41
# 1     38           5           0.05              5.0              46
# 2     40           5           0.05              5.0              51
# 37    41           1           0.01              1.0              52
# 38    42           1           0.01              1.0              53
# 34    43           1           0.01              1.0              54
# 23    44           2           0.02              2.0              56
# 21    45           2           0.02              2.0              58
# 20    46           2           0.02              2.0              60
# 33    47           1           0.01              1.0              61
# 43    48           1           0.01              1.0              62
# 14    49           2           0.02              2.0              64
# 15    50           2           0.02              2.0              66
# 18    51           2           0.02              2.0              68
# 41    52           1           0.01              1.0              69
# 42    53           1           0.01              1.0              70
# 13    55           3           0.03              3.0              73
# 7     56           4           0.04              4.0              77
# 16    57           2           0.02              2.0              79
# 27    58           2           0.02              2.0              81
# 32    60           1           0.01              1.0              82
# 3     62           4           0.04              4.0              86
# 9     63           3           0.03              3.0              89
# 11    64           3           0.03              3.0              92
# 44    65           1           0.01              1.0              93
# 30    66           1           0.01              1.0              94
# 10    67           3           0.03              3.0              97
# 25    68           2           0.02              2.0              99
# 36    69           1           0.01              1.0             100
